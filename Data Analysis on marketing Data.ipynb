# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("marketing_data.csv")

# %%
data.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
data.tail()
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 2235         1      3/7/13       99       372  ...                 11
# 2236         0     1/22/13       99         5  ...                  3
# 2237         0     12/3/12       99       185  ...                  5
# 2238         0    11/29/12       99       267  ...                 10
# 2239         2      9/1/12       99       169  ...                  4
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# ...

# %%
data.shape
# Out:
# (2240, 28)

# %%
data.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
data.columns=data.columns.str.replace(" ", "")

# %%
data['Income']=data['Income'].str.strip('$')
data['Income']=data['Income'].str.replace(',','')
data['Income']
# Out:
# 0       84835.00
# 1       57091.00
# 2       67267.00
# 3       32474.00
# 4       21474.00
#           ...
# 2235    66476.00
# 2236    31056.00
# 2237    46310.00
# 2238    65819.00
# 2239    94871.00
# Name: Income, Length: 2240, dtype: object

# %%
data['Income']=data['Income'].astype('float')
data['Income'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ## Analyse Income

# %% [markdown]
# * Numerical type column, Categorical

# %%
data['Income'].mean()
# Out:
# 52247.25135379061

# %%
data['Income'].median()
# Out:
# 51381.5

# %%
data['Income'].std()
# Out:
# 25173.0766609014

# %%
data['Income'].max()
# Out:
# 666666.0

# %%
data['Income'].min()
# Out:
# 1730.0

# %%
data['Income'].plot(kind='hist',figsize=(18,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Income'].plot(kind='kde',figsize=(18,5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
clean_data=data[data['Income']<200000]
clean_data['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
clean_data['Income'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
clean_data['Income'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
print(data['Income'].mean())
print(clean_data['Income'].mean())
# Out:
# 52247.25135379061
# 51969.861399548536

# %%
print(data['Income'].median())
print(clean_data['Income'].median())
# Out:
# 51381.5
# 51373.0

# %%
print(data['Income'].std())
print(clean_data['Income'].std())
# Out:
# 25173.0766609014
# 21526.320094910978

# %%
data['Income'].max()-data['Income'].min()
# Out:
# 664936.0

# %% [markdown]
# IQR

# %%
q1=data['Income'].quantile(0.25)
q3=data['Income'].quantile(0.75)

# %%
q1
# Out:
# 35303.0

# %%
q3
# Out:
# 68522.0

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 33219.0

# %%
lower_bound=q1 - 1.5*IQR
upper_bound=q3 + 1.5*IQR

# %%
lower_bound
# Out:
# -14525.5

# %%
upper_bound
# Out:
# 118350.5

# %%
cleaned_data=data[(data['Income']<upper_bound) & (data['Income']>lower_bound)]

# %%
cleaned_data['Income'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cleaned_data['Income'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
cleaned_data['Income'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Column is numeric type

# %% [markdown]
# -- univariate- box, kde, dist, hist, statistical summary

# %% [markdown]
# ### Column is categorical type

# %% [markdown]
# -- univaiate- count, pie, mode

# %%
data['Income'].plot()
# Out:
# <AxesSubplot:>

# %%
data.dropna(inplace=True)

# %%
data['Education'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Marital_Status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Marital_Status'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# * Checking the relationship between 2 columns
# * numeracal & numerical - scatter plot
# * numerical & categorical- box plot, barplot
# * categorical & categorical - stacked barchart, crosstabs

# %%
data['age']=2023-data['Year_Birth']
data.head()
# Out:
#       ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumWebVisitsMonth  AcceptedCmp3  \
# 0     6/16/14        0       189  ...                  1             0
# 1     6/15/14        0       464  ...                  5             0
# 2     5/13/14        0       134  ...                  2             0
# 3     5/11/14        0        10  ...                  7             0
# 4      4/8/14        0         6  ...                  7             1
#
#    AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  \
# ...

# %% [markdown]
# ### Numerical vs Numerical

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(y='MntWines', x='Income', data=cleaned_data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='MntWines'>

# %%
cleaned_data['MntGoldProds'].mean()
# Out:
# 44.11096014492754

# %%
data['MntGoldProds'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(y='MntGoldProds', x='Income', data=cleaned_data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='MntGoldProds'>

# %% [markdown]
# ### Numerical vs Categorical

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y='MntWines', x='Education', data=cleaned_data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MntWines'>

# %%
sns.barplot(x='Country', y='Income', data=cleaned_data, ci=None)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Income'>

# %% [markdown]
# ### categorical & categorical - stacked barchart, crosstabs

# %%
pd.crosstab(index=data['Education'],columns=data['Country']).sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12692\3574783385.py in <module>
# ----> 1 pd.crosstab(index=data['Education'],columns=data['Country']).sort_values()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
data[data['Country']=='ME']

# %% [markdown]
# ## Multivariate analaysis

# %%
data.corr()

# %% [markdown]
# ### Numerical

# %%
num_col=cleaned_data.select_dtypes(include=['int64','float64'])

# %%
num_col.columns

# %% [markdown]
# ### Categorical

# %%
cat_col=cleaned_data.select_dtypes(include='object')
cat_col.columns

# %%
num_col=num_col.drop(['ID', 'Response', 'Complain','AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2'], axis=1)

# %%
len(num_col.columns)

# %%
num_col.columns

# %%
num_col.plot(kind='kde', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False)

# %%
num_col.plot(kind='hist', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False);

# %%
num_col.plot(kind='box', figsize=(20,10), subplots=True, layout=(4,5), sharex=False, sharey=False);
